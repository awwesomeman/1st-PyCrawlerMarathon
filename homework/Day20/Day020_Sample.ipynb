# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 下載檔案

# %%
import requests 
url = 'https://taqm.epa.gov.tw/taqm/tw/MonthlyAverage.aspx'
payload = {
    'ctl05$ddlSite': 14,
    'ctl05$ddlYear': 2015,
    'ctl05$btnQuery': '查詢',
    'ScriptManager1': 'ctl05$UpdatePanel1|ctl05$btnQuery',
    '__VIEWSTATE': '...',
    '__VIEWSTATEGENERATOR': '0C858E1A',
    '__EVENTVALIDATION': '...'
}
r = requests.post(url, data=payload)
r.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW">\r\n<head id="Head1"><base href=\'https://taqm.epa.gov.tw/taqm/tw/\' /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><title>\r\n\t行政院環境保護署－空氣品質監測網 - 月平均值查詢\r\n</title><meta name="title" content="空氣品質監測網(TAQM)" />\r\n<!--link rel="govtwsimpledc.xsd" href="http://www.gov.tw/schema/dc/" title="Dublin Core" /--> \r\n<link type="text/css" href="/taqm/tw/style/all.min.css?v=20180508c" rel="stylesheet" />\r\n<script type="text/javascript" src="/taqm/script/jquery.min.js"></script>\r\n<script type="text/javascript" src="/taqm/script/jquery.myslide2.min.js"></script>\r\n<script type="text/javascript">\r\nfunction DownloadReport(url) {\r\n\tvar win = window.open("DownloadReport.aspx?file="+escape(url),"download" /*,"modal=yes,menubar=no,scrollbars=no,status=no,titlebar=no,toolbar=no,height=200px,width=300px"*/);\r\n\tif ( win ) {\r\n\t\twin.focus();\r\n\t} // if\r\n}\r\n</script>\r\n<meta name="DC.Title" content="行政院環境保護署-空氣品質資訊網" />\r\n<meta name="DC.Creator" content="行政院環境保護署-環境監測及資訊處" />\r\n<meta name="DC.Contributor" content="行政院環境保護署-空氣品質資訊網" />\r\n<meta name="DC.Source" content="行政院環境保護署-環境監測及資訊處" />\r\n<meta name="DC.Publisher" content="行政院環境保護署-環境監測及資訊處" />\r\n<meta name="DC.Rights" content="行政院環境保護署" />\r\n<meta name="DC.Type" content="text/html" />\r\n<meta name="DC.Format" content="text" />\r\n<meta name="DC.Language" content="中文" />\r\n<meta name="DC.coverage.t.max" content="2007-12-13" />\r\n<meta name="DC.coverage.t.min" content="2010-12-31" />\r\n<meta name="DC.Date" content="2007-12-10 17:08 " />\r\n</head>\r\n<body>\r\n    <form name="form1" method="post" action="/taqm/tw/MonthlyAverage.aspx" id="form1">\r\n<div>\r\n<input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />\r\n</div>\r\n\r\n\r\n<script src="/taqm/ScriptResource.axd?d=9oXdG9MQ6pX8Flaojk-WqhTitI2cIYjXjhMSrYnm4JLDHVEDUtxX-uxNzbndEm3YnGGvmYapYjzAvua9vz4etaAzpoy_rvxY_wSqi3VYkNayYGz5GeTIsREdLiSzNxbdw_GfHIwOQijoejPHt-4nwqF4Yvs1&amp;t=635683397975186168" type="text/javascript"></script>\r\n<div>\r\n\r\n\t<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="0C858E1A" />\r\n\t<input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="..." />\r\n</div>\r\n        \r\n<div id="outer-wrapper">\r\n<!-- outer-wrapper -->\r\n<div id="header-wrapper">\r\n<!-- header-wrapper -->\r\n<div id="header-inner">\r\n<div id="header-menu"><span id="header-menu-span"><a accesskey="T" ></a><a accesskey="U" class="access" href="SiteMap.aspx" title="上方導覽連結區"> ::: </a> <a href=\'https://taqm.epa.gov.tw/taqm/tw/SiteMap.aspx\'>網站地圖</a>｜<span id="Languages1_labHtml"><a href=\'/taqm/en/MonthlyAverage.aspx\' target=\'en\'>English</a>｜</span>\r\n<a href=\'https://epamail.epa.gov.tw/front/mailboxhome\' target="_blank">意見信箱</a>｜<a href=\'https://taqm.epa.gov.tw/taqm/tw/b0902.aspx\'>常見問題</a></span></div>\r\n<a href="https://www.epa.gov.tw/"><img src="../resource/pixel.gif" id="picHome" title="回環保署首頁" alt="回環保署首頁" style="border:0;width:260px;height:50px" border="0" /></a>\r\n</div>\r\n<!-- header-wrapper -->\r\n</div>\r\n\r\n<div id="content-wrapper"><!-- content-wrapper -->\r\n<table class="box" data-summary="layout" >\r\n<tr><td style="width:170px" class="td_valign_top">\r\n\r\n<div id="menu-wrapper"><!-- menu-wrapper -->\r\n<a accesskey="L" class="access" href="SiteMap.aspx" title="左側主選單"> ::: </a>\r\n<!-- BOX START -->\r\n<table data-summary="layout" class="box" ><tbody>\r\n              <tr>\r\n                <td class="up-left"></td>\r\n                <td class="up"></td>\r\n                <td class="up-right"></td></tr>\r\n              <tr>\r\n                <td class="left"></td>\r\n                <td class="content">\r\n<!-- CONTENT START -->\r\n<div class="box-title"><h1 id="MainMenu"><a href="default.aspx" id="XF09S" title="回空氣品質監測網首頁"><b>空氣品質監測網</b></a></h1></div> ...

# %% [markdown]
# ## 作業目標
#
#
# * 取出 台北市士林區 2018/01 – 2018/08 的 SO2 資料
